# %% [markdown]
# # 02_exploratory_analysis
# Perform EDA on processed datasets.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

ucs = pd.read_csv('../data/processed/UCS_CBR_processed.csv')

sns.pairplot(ucs, hue='Material')
plt.show()
